# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\mohit\Downloads\AB_NYC_2019 (1).csv"
              )

# %%
df
# Out:
#          id                                              name  host_id  \
# 0      2539                Clean & quiet apt home by the park     2787
# 1      2595                             Skylit Midtown Castle     2845
# 2      3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3      3831                   Cozy Entire Floor of Brownstone     4869
# 4      5022  Entire Apt: Spacious Studio/Loft by central park     7192
# ...     ...                                               ...      ...
# 48901  5441                   Central Manhattan/near Broadway     7989
# 48902  5803    Lovely Room 1, Garden, Best Area, Legal rental     9744
# 48903  6021  Wonderful Guest Bedroom in Manhattan for SINGLES    11528
# 48904  6090                     West Village Nest - Superhost    11975
# 48905  6848                  Only 2 stops to Manhattan studio    15991
#
#            host_name neighbourhood_group    neighbourhood  latitude  \
# ...

# %%
df.dropna(inplace =True)
df.drop_duplicates(inplace=True)

# %%
df["id"]=df["id"].astype(str)
df["host_id"]=df["host_id"].astype(str)
df["latitude"]=df["latitude"].astype(str)
df["longitude"]=df["longitude"].astype(str)

# %%
df.describe()
# Out:
#               price  minimum_nights  number_of_reviews  reviews_per_month  \
# count  38821.000000    38821.000000       38821.000000       38821.000000
# mean     142.332526        5.869220          29.290255           1.373229
# std      196.994756       17.389026          48.182900           1.680328
# min        0.000000        1.000000           1.000000           0.010000
# 25%       69.000000        1.000000           3.000000           0.190000
# 50%      101.000000        2.000000           9.000000           0.720000
# 75%      170.000000        4.000000          33.000000           2.020000
# max    10000.000000     1250.000000         629.000000          58.500000
#
#        calculated_host_listings_count  availability_365
# count                    38821.000000      38821.000000
# mean                         5.166611        114.886299
# std                         26.302954        129.529950
# min                          1.000000          0.000000
# ...

# %%
df.nunique()
# Out:
# id                                38821
# name                              38244
# host_id                           30232
# host_name                          9885
# neighbourhood_group                   5
# neighbourhood                       218
# latitude                          17436
# longitude                         13639
# room_type                             3
# price                               581
# minimum_nights                       89
# number_of_reviews                   393
# last_review                        1764
# reviews_per_month                   937
# calculated_host_listings_count       47
# availability_365                    366
# dtype: int64

# %%
df["neighbourhood_group"].value_counts()
# Out:
# neighbourhood_group
# Manhattan        16621
# Brooklyn         16439
# Queens            4572
# Bronx              875
# Staten Island      314
# Name: count, dtype: int64

# %%
df["neighbourhood_group"].value_counts(normalize =True)
# Out:
# neighbourhood_group
# Manhattan        0.428145
# Brooklyn         0.423456
# Queens           0.117771
# Bronx            0.022539
# Staten Island    0.008088
# Name: proportion, dtype: float64

# %%
df["room_type"].value_counts()
# Out:
# room_type
# Entire home/apt    20321
# Private room       17654
# Shared room          846
# Name: count, dtype: int64

# %%
df["room_type"].value_counts(normalize =True)
# Out:
# room_type
# Entire home/apt    0.523454
# Private room       0.454754
# Shared room        0.021792
# Name: proportion, dtype: float64

# %%
df["neighbourhood"].value_counts()
# Out:
# neighbourhood
# Williamsburg          3163
# Bedford-Stuyvesant    3141
# Harlem                2204
# Bushwick              1942
# Hell's Kitchen        1528
#                       ...
# Holliswood               2
# New Dorp Beach           2
# Richmondtown             1
# Rossville                1
# Willowbrook              1
# Name: count, Length: 218, dtype: int64

# %%
df_n=df["neighbourhood"].value_counts().reset_index().rename(columns = {"index":"neighbourhood","neighbourhood":"number_of_hotels"})

# %%
df_n
# Out:
#        number_of_hotels  count
# 0          Williamsburg   3163
# 1    Bedford-Stuyvesant   3141
# 2                Harlem   2204
# 3              Bushwick   1942
# 4        Hell's Kitchen   1528
# ..                  ...    ...
# 213          Holliswood      2
# 214      New Dorp Beach      2
# 215        Richmondtown      1
# 216           Rossville      1
# 217         Willowbrook      1
#
# [218 rows x 2 columns]

# %%
df_n[df_n["number_of_hotels"]>1000]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 df_n[df_n["number_of_hotels"]>1000]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\ops\common.py:81, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      77             return NotImplemented
#      79 other = item_from_zerodim(other)
# ---> 81 return method(self, other)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\arraylike.py:56, in OpsMixin.__gt__(self, other)
#      54 @unpack_zerodim_and_defer("__gt__")
#      55 def __gt__(self, other):
# ---> 56     return self._cmp_method(other, operator.gt)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:6096, in Series._cmp_method(self, other, op)
#    6093 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
#    6095 with np.errstate(all="ignore"):
# ...

# %%
df["price"].value_counts(bins=5)
# Out:
# price
# (-10.001, 2000.0]    38786
# (2000.0, 4000.0]        20
# (4000.0, 6000.0]         8
# (8000.0, 10000.0]        5
# (6000.0, 8000.0]         2
# Name: count, dtype: int64

# %%
df["price"].value_counts(bins=10)
# Out:
# price
# (-10.001, 1000.0]    38714
# (1000.0, 2000.0]        72
# (2000.0, 3000.0]        17
# (4000.0, 5000.0]         6
# (9000.0, 10000.0]        4
# (3000.0, 4000.0]         3
# (5000.0, 6000.0]         2
# (7000.0, 8000.0]         2
# (8000.0, 9000.0]         1
# (6000.0, 7000.0]         0
# Name: count, dtype: int64

# %%
bins=(0,50,100,200,500,2000,4000,6000)

# %%
df["price"].value_counts(bins=bins)
# Out:
# price
# (50.0, 100.0]       14212
# (100.0, 200.0]      13544
# (200.0, 500.0]       5267
# (-0.001, 50.0]       5176
# (500.0, 2000.0]       587
# (2000.0, 4000.0]       20
# (4000.0, 6000.0]        8
# Name: count, dtype: int64

# %%
df["price"].mean()
# Out:
# 142.33252621004095

# %%
df["price"].std()
# Out:
# 196.99475591833985

# %%
df["price"].skew()
# Out:
# 23.673594295123014

# %%
df["price"].kurt()
# Out:
# 953.4807356344944

# %%
#(df.corr())

# %% [markdown]
# # univariate by using categorical data

# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\mohit\Downloads\AB_NYC_2019 (1).csv")

# %%
df.head(2)
# Out:
#      id                                name  host_id host_name  \
# 0  2539  Clean & quiet apt home by the park     2787      John
# 1  2595               Skylit Midtown Castle     2845  Jennifer
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0    149               1                  9  19-10-2018               0.21
# 1    225               1                 45  21-05-2019               0.38
#
#    calculated_host_listings_count  availability_365
# 0                               6               365
# 1                               2               355

# %% [markdown]
# # Categorical

# %% [markdown]
# # Bar graph

# %%
sns.countplot(data=df,x="neighbourhood_group")
# Out:
# <Axes: xlabel='neighbourhood_group', ylabel='count'>

# %%
sns.countplot(data=df,x="neighbourhood")
# Out:
# <Axes: xlabel='neighbourhood', ylabel='count'>

# %%
sns.countplot(data=df,x='room_type')
# Out:
# <Axes: xlabel='room_type', ylabel='count'>

# %%
sns.countplot(data=df,x='neighbourhood_group', hue = 'room_type')
# Out:
# <Axes: xlabel='neighbourhood_group', ylabel='count'>

# %% [markdown]
# # piecharts

# %%
df["room_type"].value_counts().plot(kind='pie',autopct= "%.2f")
# Out:
# <Axes: ylabel='count'>

# %%
df["neighbourhood_group"].value_counts().plot(kind='pie',autopct= "%.2f")
# Out:
# <Axes: ylabel='count'>

# %%
df["neighbourhood_group"].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='neighbourhood_group'>

# %%
df2=sns.load_dataset('titanic')

# %%
df2.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.countplot(data=df2,x="survived",hue="sex")
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
sns.countplot(data=df2,x="class",hue="survived")
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
df2["class"].value_counts().plot(kind="pie",autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # Histogram

# %%
import pandas as pd
import seaborn as sns
df=pd.read_csv(r"C:\Users\mohit\Downloads\AB_NYC_2019 (1).csv")
sns.histplot(data = df ,x='price')
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
sns.histplot(data =df [df["price"]<500], x = "price")
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
sns.histplot(data =df [df["availability_365"]<500], x = "availability_365")
# Out:
# <Axes: xlabel='availability_365', ylabel='Count'>

# %% [markdown]
# # Distribution

# %%
import seaborn as sns
import pandas as pd
df=pd.read_csv(r"C:\Users\mohit\Downloads\AB_NYC_2019 (1).csv")
sns.distplot(df["availability_365"])
# Out:
# C:\Users\mohit\AppData\Local\Temp\ipykernel_1680\1316468826.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["availability_365"])
# <Axes: xlabel='availability_365', ylabel='Density'>

# %%
sns.distplot(df["reviews_per_month"])
# Out:
# C:\Users\mohit\AppData\Local\Temp\ipykernel_1680\2533210752.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["reviews_per_month"])
# <Axes: xlabel='reviews_per_month', ylabel='Density'>

# %% [markdown]
# # Boxplot

# %%
sns.boxplot(df["reviews_per_month"])
# Out:
# <Axes: >

# %%
sns.boxplot(df["price"])
# Out:
# <Axes: >

# %%
sns.boxplot(df["host_id"])
# Out:
# <Axes: >

# %%
sns.boxplot(df["availability_365"])
# Out:
# <Axes: >

# %%
df2=sns.load_dataset('titanic')

# %%
df2
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df2.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.histplot(data=df2,x="fare")
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
sns.distplot(df2["fare"])
# Out:
# C:\Users\mohit\AppData\Local\Temp\ipykernel_1680\3524834500.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df2["fare"])
# <Axes: xlabel='fare', ylabel='Density'>

# %%
sns.boxplot(df2["fare"])
# Out:
# <Axes: >

# %%
sns.boxplot(df2["age"])
# Out:
# <Axes: >

# %%
sns.violinplot(df2["age"])
# Out:
# <Axes: >

# %% [markdown]
# # Bivariate analysis.

# %%
import pandas as pd
import seaborn as sns
df=sns.load_dataset("titanic")
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.barplot(x="class",y="age",data=df,estimator="sum")
# Out:
# <Axes: xlabel='class', ylabel='age'>

# %%
sns.barplot(x="class",y="fare",data=df, estimator="sum")
# Out:
# <Axes: xlabel='class', ylabel='fare'>

# %%
#by using hue ufnction we can categorise the x axis
sns.barplot(x="class", y="age",hue="sex", 
            data=df)
# Out:
# <Axes: xlabel='class', ylabel='age'>

# %%
sns.barplot(x="class", y="fare",hue="sex", 
            estimator ="sum")
# Out:
# <Axes: xlabel='class', ylabel='fare'>

# %%
sns.boxplot(x="class", y="age",hue="survived",data=df)
# Out:
# <Axes: xlabel='class', ylabel='age'>

# %%
sns.violinplot(x="class",y="age",data=df)
# Out:
# <Axes: xlabel='class', ylabel='age'>

# %%
import pandas as pd
import seaborn as sns
df=sns.load_dataset("titanic")
sns.distplot(df[df["class"] == "second"]["age"])
# Out:
# C:\Users\mohit\AppData\Local\Temp\ipykernel_1680\4284585214.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df["class"] == "second"]["age"])
# C:\Users\mohit\anaconda3\Lib\site-packages\seaborn\distributions.py:2479: RuntimeWarning: Mean of empty slice.
#   line, = ax.plot(a.mean(), 0)
# C:\Users\mohit\anaconda3\Lib\site-packages\numpy\core\_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\mohit\anaconda3\Lib\site-packages\numpy\lib\histograms.py:883: RuntimeWarning: invalid value encountered in divide
#   return n/db/n.sum(), bin_edges
# ...

# %%
#we can plot categorical data using ,barplot,boxplot,violinplot

# %% [markdown]
# # bivariate visualization for categorical data.

# %%
import pandas as pd
import seaborn as sns
df=sns.load_dataset("titanic")

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.countplot(x="survived",hue="class",data=df)
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
x=pd.crosstab(df["survived"],df["class"])

# %%
x
# Out:
# class     First  Second  Third
# survived
# 0            80      97    372
# 1           136      87    119

# %%
#Heatmap

sns.heatmap(x,annot=True,fmt=".1f",cmap="coolwarm")
# Out:
# <Axes: xlabel='class', ylabel='survived'>

# %%
sns.barplot(x="class",y="age",hue='sex',data=df)
# Out:
# <Axes: xlabel='class', ylabel='age'>

# %%
sns.stripplot(x="class",y="age",hue='sex',data=df)
# Out:
# <Axes: xlabel='class', ylabel='age'>

# %%
import seaborn as sns
df2=sns.load_dataset("iris")
df2.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df2.head(10).plot(kind="bar")
# Out:
# <Axes: >

# %%
df2.head(10).plot(kind="bar",stacked=True)
# Out:
# <Axes: >

# %%
sns.pairplot(df2.head())
# Out:
# C:\Users\mohit\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#bivariate analysis for numerical data

# %% [markdown]
# # scatter plot

# %%
df2=sns.load_dataset("tips")
df2.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(x="total_bill",y="tip",hue="sex",style="smoker",data=df2)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# # jointplot-it gives both scatterplot and histogram.

# %%
sns.jointplot(x="total_bill",y="tip",data=df2)

# %%
sns.jointplot(x="total_bill",y="tip",hue="sex",data=df2)

# %%
sns.jointplot(x="total_bill",y="tip",data=df2,kind="reg")

# %%
#to get all dataset of seaborn.

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic',
#  'anagrams',
#  'anagrams',
#  'anscombe',
#  'anscombe',
#  'attention',
#  'attention',
#  'brain_networks',
#  'brain_networks',
#  'car_crashes',
#  'car_crashes',
#  'diamonds',
#  'diamonds',
#  'dots',
#  'dots',
#  'dowjones',
#  'dowjones',
#  'exercise',
#  'exercise',
#  'flights',
#  'flights',
#  'fmri',
#  'fmri',
#  'geyser',
#  'geyser',
#  'glue',
#  'glue',
#  'healthexp',
#  'healthexp',
#  'iris',
#  'iris',
#  'mpg',
#  'mpg',
#  'penguins',
#  'penguins',
#  'planets',
#  'planets',
#  'seaice',
#  'seaice',
#  'taxis',
#  'taxis',
#  'tips',
#  'tips',
#  'titanic',
#  'titanic',
#  'anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
# ...

# %%
df2=sns.load_dataset("dowjones")

# %%
df2.head()
# Out:
#         Date  Price
# 0 1914-12-01  55.00
# 1 1915-01-01  56.55
# 2 1915-02-01  56.00
# 3 1915-03-01  58.30
# 4 1915-04-01  66.45

# %%
#lineplot

sns.lineplot(x = "Date", y = "Price", data = df2)
# Out:
# <Axes: xlabel='Date', ylabel='Price'>

# %%
df2["Month"] = df2["Date"].dt.month
df2["Year"] = df2["Date"].dt.year

# %%
df2.head()
# Out:
#         Date  Price  Month  Year
# 0 1914-12-01  55.00     12  1914
# 1 1915-01-01  56.55      1  1915
# 2 1915-02-01  56.00      2  1915
# 3 1915-03-01  58.30      3  1915
# 4 1915-04-01  66.45      4  1915

# %%
#lineplot-IT HELPS TO CHECK THE TRENDS OVER TIME
#TWO NUMERICAL PLOT-scatterplot.
#distribution of two numerical columns- jointplot

sns.lineplot(x = "Date", y = "Price", data = df2[df2["Year"]==1925])
# Out:
# <Axes: xlabel='Date', ylabel='Price'>
